# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/home/cmf/Pictures/opencv.jpg')

# %%
img = cv2.rectangle(img, (20, 20), (100, 100), (255, 0, 0), 5)

# %%
plt.imshow(img)

# %%
import tempfile

# %%
tempfile.NamedTemporaryFile()

# %%
from xml.etree import ElementTree as etree
from xml.etree.ElementTree import Element, SubElement, ElementTree
 
# 生成根节点
root = Element('root')
# 生成第一个子节点 head
head = SubElement(root, 'head')
# head 节点的子节点
title = SubElement(head, 'title')
title.text = 'Well Dola!'
# 生成 root 的第二个子节点 body
body = SubElement(root, 'body')
# body 的内容
body.text = 'I love Dola!'
tree = ElementTree(root)
# 第一种
tree.write('result.xml', encoding='utf-8')

# %%
tree = etree.parse('result.xml')
root = tree.getroot()

# %%
head1 = SubElement(root, 'head1')
head1.text='body1'
# tree = ElementTree(root)
tree.write('result.xml', encoding='utf-8')
